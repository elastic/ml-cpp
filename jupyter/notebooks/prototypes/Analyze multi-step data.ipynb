# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False
from incremental_learning.config import es_cloud_id, es_user, es_password
import numpy as np
import plotly.graph_objects as go
import plotly.io as pio
from plotly.subplots import make_subplots

from elasticsearch import Elasticsearch


import eland as ed

import ipywidgets as widgets
from ipywidgets import interact, Layout, interactive_output
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def plot_errors(sampling_mode, update_fraction, training_fraction, dataset_name):
    if sampling_mode:
        dataset = df1[(df1['config.sampling_mode'] == sampling_mode)]
    else:
        dataset = df1
    if update_fraction:
        dataset =  dataset[(dataset['config.update_fraction'] == update_fraction)]
    if training_fraction:
        dataset =  dataset[(dataset['config.training_fraction'] == training_fraction)]
    if dataset_name:
        dataset =  dataset[(dataset['config.dataset_name'] == dataset_name)]
        
    x_base = np.arange(10)+1
    
    fig = go.Figure()
    for row in dataset.iterrows():
        text = ["{}: {}".format(k, v) for k,v in row[1][['config.sampling_mode', 'config.update_fraction', 
                          'config.training_fraction', 'config.seed']].items()]
        text = '<br>'.join(text)
        x = x_base*row[1]['config.update_fraction'] + row[1]['config.training_fraction']
        if len(row[1]['run.result.updated_model.train_error.value']) == 10:
            fig.add_trace(go.Scatter(x=x, y=row[1]['run.result.updated_model.train_error.value'], text=text))
    fig.update_layout(title="Train error", xaxis_title='Fraction observed', 
            yaxis_title="MSE")
    fig.show()

    fig = go.Figure()
    for row in dataset.iterrows():
        text = ["{}: {}".format(k, v) for k,v in row[1][['config.sampling_mode', 'config.update_fraction', 
                          'config.training_fraction', 'config.seed']].items()]
        text = '<br>'.join(text)
        x = x_base*row[1]['config.update_fraction'] + row[1]['config.training_fraction']
        if len(row[1]['run.result.updated_model.test_error.value']) == 10:
            fig.add_trace(go.Scatter(x=x, y=row[1]['run.result.updated_model.test_error.value'], text=text))
    fig.update_layout(title="Test error", xaxis_title='Fraction observed', 
            yaxis_title="MSE")
    fig.show()

# %%
es = Elasticsearch(cloud_id=es_cloud_id,
                       http_auth=(es_user, es_password))

df = ed.DataFrame(es_client=es, es_index_pattern='experiment-multi-step-sampling', columns=['config.dataset_name', 'run.result.updated_model.train_error.value', 
                      'run.result.updated_model.test_error.value', 'config.sampling_mode', 'config.update_fraction', 
                      'config.training_fraction', 'config.seed'])

df1 = df.to_pandas().dropna()

# %%
# layout = Layout(display='flex', flex_flow='row', justify_content='space-between')
w_dataset_name = widgets.Dropdown(options=df1['config.dataset_name'].unique(), value='house', 
                                   description="Dataset_name", disabled=False)
w_sampling_mode = widgets.Dropdown(options=df1['config.sampling_mode'].unique(), value=None, 
                                   description="Sampling mode", disabled=False)
w_update_fraction = widgets.Dropdown(options=df1['config.update_fraction'].unique(), value=None, 
                                     description="Update fraction", disabled=False)
w_training_fraction = widgets.Dropdown(options=df1['config.training_fraction'].unique(), value=None, 
                                       description="Training fraction", disabled=False)
ui = widgets.HBox([w_dataset_name, w_sampling_mode, w_update_fraction, w_training_fraction])
out = interact(plot_errors, dataset_name = w_dataset_name, sampling_mode=w_sampling_mode, 
             update_fraction = w_update_fraction, training_fraction=w_training_fraction)
# Out:
# interactive(children=(Dropdown(description='Sampling mode', options=('nlargest', 'random'), value=None), Dropd…

# %%
df1[(df1["config.dataset_name"] == 'facebook')].dropna()
# Out:
#                      config.dataset_name  \
# NndFnXwBUYUoev8FgBGq            facebook
# 63cDpXwBUYUoev8FYhE3            facebook
# 83dipXwBUYUoev8FHRG_            facebook
# TXcAqnwBUYUoev8FlxI9            facebook
# S3fsqXwBUYUoev8FJBLE            facebook
# Lnd3qHwBUYUoev8F9BIm            facebook
# -3fBpXwBUYUoev8FzhEs            facebook
# z3dPsHwBUYUoev8FDBK6            facebook
# 0HdPsHwBUYUoev8FfBKJ            facebook
# YnegqnwBUYUoev8FNRK1            facebook
# 13eisHwBUYUoev8FNBI3            facebook
# bHfotnwBUYUoev8FsBN9            facebook
# zHcwsHwBUYUoev8FbxLA            facebook
# TnfJtnwBUYUoev8F1BPG            facebook
# 53dosXwBUYUoev8F-RJ8            facebook
# _neUsnwBUYUoev8F6BKt            facebook
# rnefrnwBUYUoev8FJRId            facebook
# p3eVuHwBUYUoev8F3BP0            facebook
# 3Xdbu3wBUYUoev8FSxMD            facebook
# tXc-uXwBUYUoev8FqBNL            facebook
# r3fvuHwBUYUoev8F5hMv            facebook
# rXcalnwBUYUoev8F2BDN            facebook
# mHcJlXwBUYUoev8F5hA2            facebook
# 03cXmHwBUYUoev8FhxA9            facebook
# C3cRm3wBUYUoev8FHhEF            facebook
# yXeqo3wBUYUoev8F-hEf            facebook
# ynero3wBUYUoev8FsBEr            facebook
# yHepo3wBUYUoev8F8BEl            facebook
# y3eso3wBUYUoev8FbxHu            facebook
# T3cCqnwBUYUoev8FBxIa            facebook
# TncBqnwBUYUoev8FShLO            facebook
# V3cXqnwBUYUoev8FZRKB            facebook
# enczt3wBUYUoev8FKROA            facebook
# bXfptnwBUYUoev8FphN1            facebook
#
#                              run.result.updated_model.train_error.value  \
# NndFnXwBUYUoev8FgBGq  [224.234803423985, 134.8236830908232, 134.8236...
# 63cDpXwBUYUoev8FYhE3  [246.8351697587024, 246.8351697587024, 156.772...
# 83dipXwBUYUoev8FHRG_  [230.6992257018419, 128.6263632156568, 128.626...
# TXcAqnwBUYUoev8FlxI9  [304.6568239873566, 304.6568239873566, 304.656...
# S3fsqXwBUYUoev8FJBLE  [324.5287687359223, 324.5287687359223, 324.528...
# Lnd3qHwBUYUoev8F9BIm  [390.1605412852457, 390.1605412852457, 323.275...
# -3fBpXwBUYUoev8FzhEs  [395.8675035308161, 395.8675035308161, 351.868...
# z3dPsHwBUYUoev8FDBK6  [304.6568239873566, 304.6568239873566, 304.656...
# 0HdPsHwBUYUoev8FfBKJ  [304.6568239873566, 304.6568239873566, 304.656...
# YnegqnwBUYUoev8FNRK1  [276.6931256332166, 144.67571911774428, 144.67...
# 13eisHwBUYUoev8FNBI3  [331.553088147651, 331.553088147651, 331.55308...
# bHfotnwBUYUoev8FsBN9  [331.553088147651, 331.553088147651, 331.55308...
# zHcwsHwBUYUoev8FbxLA  [304.6568239873566, 304.6568239873566, 304.656...
# TnfJtnwBUYUoev8F1BPG  [331.553088147651, 331.553088147651, 331.55308...
# 53dosXwBUYUoev8F-RJ8  [342.2981161205161, 342.2981161205161, 342.298...
# _neUsnwBUYUoev8F6BKt  [258.9976900061542, 258.9976900061542, 258.997...
# rnefrnwBUYUoev8FJRId  [317.2948332973353, 317.2948332973353, 317.294...
# p3eVuHwBUYUoev8F3BP0  [305.7707956033345, 210.11827715607154, 188.55...
# 3Xdbu3wBUYUoev8FSxMD  [315.98293924967317, 245.6477641183624, 245.64...
# tXc-uXwBUYUoev8FqBNL  [251.09457455798886, 251.09457455798886, 251.0...
# r3fvuHwBUYUoev8F5hMv  [316.94677619394287, 316.94677619394287, 292.4...
# rXcalnwBUYUoev8F2BDN  [268.73873927619996, 148.9746680254779, 148.97...
# mHcJlXwBUYUoev8F5hA2  [233.77116551504886, 233.77116551504886, 150.1...
# 03cXmHwBUYUoev8FhxA9  [234.00024803462733, 234.00024803462733, 144.7...
# C3cRm3wBUYUoev8FHhEF  [271.62959355008087, 135.29800937111025, 135.2...
# yXeqo3wBUYUoev8F-hEf  [324.5287687359223, 324.5287687359223, 324.528...
# ynero3wBUYUoev8FsBEr  [324.5287687359223, 324.5287687359223, 324.528...
# yHepo3wBUYUoev8F8BEl  [324.5287687359223, 324.5287687359223, 324.528...
# y3eso3wBUYUoev8FbxHu  [324.5287687359223, 324.5287687359223, 324.528...
# T3cCqnwBUYUoev8FBxIa  [304.6568239873566, 304.6568239873566, 304.656...
# TncBqnwBUYUoev8FShLO  [304.6568239873566, 304.6568239873566, 304.656...
# V3cXqnwBUYUoev8FZRKB  [316.7680949598718, 316.7680949598718, 316.768...
# enczt3wBUYUoev8FKROA  [331.553088147651, 331.553088147651, 331.55308...
# bXfptnwBUYUoev8FphN1  [331.553088147651, 331.553088147651, 331.55308...
#
#                               run.result.updated_model.test_error.value  \
# NndFnXwBUYUoev8FgBGq  [270.1305986033704, 316.8556287640425, 316.855...
# 63cDpXwBUYUoev8FYhE3  [290.4893250714229, 290.4893250714229, 269.521...
# 83dipXwBUYUoev8FHRG_  [270.1742478184926, 306.26815448443847, 306.26...
# TXcAqnwBUYUoev8FlxI9  [372.6634242311355, 372.6634242311355, 372.663...
# S3fsqXwBUYUoev8FJBLE  [315.5524872558988, 315.5524872558988, 315.552...
# Lnd3qHwBUYUoev8F9BIm  [370.2498139849785, 370.2498139849785, 332.081...
# -3fBpXwBUYUoev8FzhEs  [376.6148687974317, 376.6148687974317, 378.441...
# z3dPsHwBUYUoev8FDBK6  [372.6634242311355, 372.6634242311355, 372.663...
# 0HdPsHwBUYUoev8FfBKJ  [372.6634242311355, 372.6634242311355, 372.663...
# YnegqnwBUYUoev8FNRK1  [289.4603473715156, 277.9086951461986, 277.908...
# 13eisHwBUYUoev8FNBI3  [316.93681769608503, 316.93681769608503, 316.9...
# bHfotnwBUYUoev8FsBN9  [316.93681769608503, 316.93681769608503, 316.9...
# zHcwsHwBUYUoev8FbxLA  [372.6634242311355, 372.6634242311355, 372.663...
# TnfJtnwBUYUoev8F1BPG  [316.93681769608503, 316.93681769608503, 316.9...
# 53dosXwBUYUoev8F-RJ8  [338.0848649264988, 338.0848649264988, 338.084...
# _neUsnwBUYUoev8F6BKt  [306.9125845067266, 306.9125845067266, 306.912...
# rnefrnwBUYUoev8FJRId  [331.6837558301184, 331.6837558301184, 331.683...
# p3eVuHwBUYUoev8F3BP0  [300.38483217307066, 365.97010575503685, 390.5...
# 3Xdbu3wBUYUoev8FSxMD  [309.50166748004517, 340.3096462645684, 340.30...
# tXc-uXwBUYUoev8FqBNL  [300.0665927457386, 300.0665927457386, 300.066...
# r3fvuHwBUYUoev8F5hMv  [314.5436952114622, 314.5436952114622, 302.587...
# rXcalnwBUYUoev8F2BDN  [288.29068363786934, 318.28625685708613, 318.2...
# mHcJlXwBUYUoev8F5hA2  [299.21046657114533, 299.21046657114533, 311.6...
# 03cXmHwBUYUoev8FhxA9  [287.5264197135066, 287.5264197135066, 278.338...
# C3cRm3wBUYUoev8FHhEF  [287.7530313879218, 277.6696955373316, 277.669...
# yXeqo3wBUYUoev8F-hEf  [315.5524872558988, 315.5524872558988, 315.552...
# ynero3wBUYUoev8FsBEr  [315.5524872558988, 315.5524872558988, 315.552...
# yHepo3wBUYUoev8F8BEl  [315.5524872558988, 315.5524872558988, 315.552...
# y3eso3wBUYUoev8FbxHu  [315.5524872558988, 315.5524872558988, 315.552...
# T3cCqnwBUYUoev8FBxIa  [372.6634242311355, 372.6634242311355, 372.663...
# TncBqnwBUYUoev8FShLO  [372.6634242311355, 372.6634242311355, 372.663...
# V3cXqnwBUYUoev8FZRKB  [336.57646855952544, 336.57646855952544, 336.5...
# enczt3wBUYUoev8FKROA  [316.93681769608503, 316.93681769608503, 316.9...
# bXfptnwBUYUoev8FphN1  [316.93681769608503, 316.93681769608503, 316.9...
#
#                      config.sampling_mode  config.update_fraction  \
# NndFnXwBUYUoev8FgBGq             nlargest                    0.05
# 63cDpXwBUYUoev8FYhE3             nlargest                    0.20
# 83dipXwBUYUoev8FHRG_             nlargest                    0.10
# TXcAqnwBUYUoev8FlxI9             nlargest                    0.10
# S3fsqXwBUYUoev8FJBLE             nlargest                    0.10
# Lnd3qHwBUYUoev8F9BIm               random                    0.10
# -3fBpXwBUYUoev8FzhEs               random                    0.05
# z3dPsHwBUYUoev8FDBK6             nlargest                    0.10
# 0HdPsHwBUYUoev8FfBKJ             nlargest                    0.10
# YnegqnwBUYUoev8FNRK1             nlargest                    0.20
# 13eisHwBUYUoev8FNBI3             nlargest                    0.10
# bHfotnwBUYUoev8FsBN9             nlargest                    0.10
# zHcwsHwBUYUoev8FbxLA             nlargest                    0.10
# TnfJtnwBUYUoev8F1BPG             nlargest                    0.10
# 53dosXwBUYUoev8F-RJ8               random                    0.20
# _neUsnwBUYUoev8F6BKt               random                    0.05
# rnefrnwBUYUoev8FJRId               random                    0.10
# p3eVuHwBUYUoev8F3BP0             nlargest                    0.05
# 3Xdbu3wBUYUoev8FSxMD             nlargest                    0.05
# tXc-uXwBUYUoev8FqBNL               random                    0.10
# r3fvuHwBUYUoev8F5hMv               random                    0.20
# rXcalnwBUYUoev8F2BDN             nlargest                    0.05
# mHcJlXwBUYUoev8F5hA2             nlargest                    0.05
# 03cXmHwBUYUoev8FhxA9             nlargest                    0.10
# C3cRm3wBUYUoev8FHhEF             nlargest                    0.10
# yXeqo3wBUYUoev8F-hEf             nlargest                    0.10
# ynero3wBUYUoev8FsBEr             nlargest                    0.10
# yHepo3wBUYUoev8F8BEl             nlargest                    0.10
# y3eso3wBUYUoev8FbxHu             nlargest                    0.10
# T3cCqnwBUYUoev8FBxIa             nlargest                    0.10
# TncBqnwBUYUoev8FShLO             nlargest                    0.10
# V3cXqnwBUYUoev8FZRKB               random                    0.05
# enczt3wBUYUoev8FKROA             nlargest                    0.10
# bXfptnwBUYUoev8FphN1             nlargest                    0.10
#
#                       config.training_fraction  config.seed
# NndFnXwBUYUoev8FgBGq                      0.50            0
# 63cDpXwBUYUoev8FYhE3                      0.10            0
# 83dipXwBUYUoev8FHRG_                      0.50            0
# TXcAqnwBUYUoev8FlxI9                      0.25            1
# S3fsqXwBUYUoev8FJBLE                      0.25            0
# Lnd3qHwBUYUoev8F9BIm                      0.10            0
# -3fBpXwBUYUoev8FzhEs                      0.10            0
# z3dPsHwBUYUoev8FDBK6                      0.25            1
# 0HdPsHwBUYUoev8FfBKJ                      0.25            1
# YnegqnwBUYUoev8FNRK1                      0.25            0
# 13eisHwBUYUoev8FNBI3                      0.25            2
# bHfotnwBUYUoev8FsBN9                      0.25            2
# zHcwsHwBUYUoev8FbxLA                      0.25            1
# TnfJtnwBUYUoev8F1BPG                      0.25            2
# 53dosXwBUYUoev8F-RJ8                      0.10            0
# _neUsnwBUYUoev8F6BKt                      0.50            0
# rnefrnwBUYUoev8FJRId                      0.25            0
# p3eVuHwBUYUoev8F3BP0                      0.10            2
# 3Xdbu3wBUYUoev8FSxMD                      0.25            2
# tXc-uXwBUYUoev8FqBNL                      0.50            0
# r3fvuHwBUYUoev8F5hMv                      0.25            0
# rXcalnwBUYUoev8F2BDN                      0.25            0
# mHcJlXwBUYUoev8F5hA2                      0.10            0
# 03cXmHwBUYUoev8FhxA9                      0.10            0
# C3cRm3wBUYUoev8FHhEF                      0.25            0
# yXeqo3wBUYUoev8F-hEf                      0.25            0
# ynero3wBUYUoev8FsBEr                      0.25            0
# yHepo3wBUYUoev8F8BEl                      0.25            0
# y3eso3wBUYUoev8FbxHu                      0.25            0
# T3cCqnwBUYUoev8FBxIa                      0.25            1
# TncBqnwBUYUoev8FShLO                      0.25            1
# V3cXqnwBUYUoev8FZRKB                      0.25            0
# enczt3wBUYUoev8FKROA                      0.25            2
# bXfptnwBUYUoev8FphN1                      0.25            2
